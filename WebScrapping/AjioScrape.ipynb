# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
# Function to extract Product Title
def get_Description(soup):

    try:
        Description = soup.find("div", attrs={"id":'fnl-plp-productdesc'})
        Description_value = Description.text       
        Description_string = Description_value.strip()

    except AttributeError:
        Description_string = ""

    return Description_string

# %%
if __name__ == '__main__':

    # add your user agent 
    HEADERS = ({'User-Agent':'', 'Accept-Language': 'en-US, en;q=0.5'})

    # The webpage URL
    URL = "https://www.Ajio.com/s?k=clothingnewtrend+4&ref=nb_sb_noss_2"

    # HTTP Request
    webpage = requests.get(URL, headers=HEADERS)

    # Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "html.parser")

    # Fetch links as List of Tag Objects
    links = soup.find_all("a", attrs={'class':'fnl-plp-producthov fnl-plp-custom'})

    # Store the links
    links_list = []

    # Loop for extracting links from Tag Objects
    for link in links:
            links_list.append(link.get('href'))

    d = {"Description":[],'URL':[]}
    
    # Loop for extracting product details from each link 
    for link in links_list:
        new_webpage = requests.get("https://www.Ajio.com" + link, headers=HEADERS)

        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        # Function calls to display all necessary product information
        d['URL'].append(link)
        d['Description'].append(get_Description(new_soup))
        

    
    Ajio_df = pd.DataFrame.from_dict(d) 
    Ajio_df = Ajio_df.dropna()
    Ajio_df.to_csv("AjioDataset.csv", header=True, index=False)

# %%
Ajio_df
# Out:
#         Unnamed: 0                                                URL  \
# 0                0  https://www.ajio.com/netplay-checked-polo-t-sh...
# 1                1  https://www.ajio.com/netplay-tapered-fit-flat-...
# 2                2  https://www.ajio.com/the-indian-garage-co-stri...
# 3                3  https://www.ajio.com/performax-heathered-crew-...
# 4                4  https://www.ajio.com/john-players-jeans-washed...
# ...            ...                                                ...
# 367167      367167  https://www.ajio.com/indie-picks-woven-pochamp...
# 367168      367168  https://www.ajio.com/indie-picks-woven-pochamp...
# 367169      367169  https://www.ajio.com/griva-designer-floral-emb...
# 367170      367170  https://www.ajio.com/global-desi-pleated-dhoti...
# 367171      367171  https://www.ajio.com/sakura-micro-print-a-line...
#
#                                             Description
# 0                                  Checked Polo T-shirt
# ...
